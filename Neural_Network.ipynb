# %%
from numpy import loadtxt
from keras.models import sequential
import numpy
from keras.models import Sequential
from keras.layers import Dense

# %% [markdown]
# from google.colab import files
# uploaded = files.upload()

# %%
data = numpy.loadtxt("diabetes.csv",delimiter = ",", skiprows=1)

X = data[:,0:8]
y = data[:,8]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test,y_train,y_test = train_test_split(X,y)

# %%
model = Sequential()
model.add(Dense(12, input_dim = 8, activation = 'relu'))
model.add(Dense(8,activation = 'relu'))
model.add(Dense(1,activation = 'sigmoid'))
# Out:
# Metal device set to: Apple M1
#
# systemMemory: 8.00 GB
# maxCacheSize: 2.67 GB
# 2022-02-02 13:05:41.366125: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2022-02-02 13:05:41.366265: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
model.compile(loss='hinge', optimizer='SGD',metrics=['accuracy'])

# %%
model.fit(x_train,y_train,epochs=50, batch_size=10)
# Out:
# Epoch 1/50
# 2022-02-02 13:25:01.527232: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 58/58 [==============================] - 1s 6ms/step - loss: 0.9777 - accuracy: 0.7344
# Epoch 2/50
# 58/58 [==============================] - 0s 6ms/step - loss: 0.9779 - accuracy: 0.6944
# Epoch 3/50
# 58/58 [==============================] - 0s 6ms/step - loss: 0.9730 - accuracy: 0.6875
# Epoch 4/50
# 58/58 [==============================] - 0s 6ms/step - loss: 0.9722 - accuracy: 0.6858
# Epoch 5/50
# 58/58 [==============================] - 0s 6ms/step - loss: 0.9680 - accuracy: 0.6892
# Epoch 6/50
# 58/58 [==============================] - 0s 6ms/step - loss: 0.9675 - accuracy: 0.6910
# Epoch 7/50
# 58/58 [==============================] - 0s 6ms/step - loss: 0.9617 - accuracy: 0.6962
# Epoch 8/50
# 58/58 [==============================] - 0s 6ms/step - loss: 0.9662 - accuracy: 0.6875
# Epoch 9/50
# 58/58 [==============================] - 0s 7ms/step - loss: 0.9645 - accuracy: 0.6927
# Epoch 10/50
# 58/58 [==============================] - 0s 5ms/step - loss: 0.9714 - accuracy: 0.6840
# Epoch 11/50
# 58/58 [==============================] - 0s 6ms/step - loss: 0.9653 - accuracy: 0.6892
# Epoch 12/50
# 58/58 [==============================] - 0s 7ms/step - loss: 0.9620 - accuracy: 0.6944
# Epoch 13/50
# 58/58 [==============================] - 0s 6ms/step - loss: 0.9625 - accuracy: 0.6944
# Epoch 14/50
# 58/58 [==============================] - 0s 6ms/step - loss: 0.9642 - accuracy: 0.6927
# Epoch 15/50
# 58/58 [==============================] - 0s 5ms/step - loss: 0.9606 - accuracy: 0.6944
# Epoch 16/50
# 58/58 [==============================] - 0s 5ms/step - loss: 0.9651 - accuracy: 0.6875
# Epoch 17/50
# 58/58 [==============================] - 0s 5ms/step - loss: 0.9631 - accuracy: 0.6892
# Epoch 18/50
# 58/58 [==============================] - 0s 6ms/step - loss: 0.9620 - accuracy: 0.6858
# Epoch 19/50
# 58/58 [==============================] - 0s 5ms/step - loss: 0.9620 - accuracy: 0.6979
# Epoch 20/50
# 58/58 [==============================] - 0s 5ms/step - loss: 0.9651 - accuracy: 0.6910
# Epoch 21/50
# 58/58 [==============================] - 0s 5ms/step - loss: 0.9617 - accuracy: 0.6962
# Epoch 22/50
# 58/58 [==============================] - 0s 5ms/step - loss: 0.9616 - accuracy: 0.6892
# Epoch 23/50
# 58/58 [==============================] - 0s 5ms/step - loss: 0.9616 - accuracy: 0.6892
# Epoch 24/50
# 58/58 [==============================] - 0s 7ms/step - loss: 0.9648 - accuracy: 0.6892
# Epoch 25/50
# 58/58 [==============================] - 0s 5ms/step - loss: 0.9644 - accuracy: 0.6858
# Epoch 26/50
# 58/58 [==============================] - 0s 5ms/step - loss: 0.9637 - accuracy: 0.6806
# Epoch 27/50
# 58/58 [==============================] - 0s 5ms/step - loss: 0.9656 - accuracy: 0.6892
# Epoch 28/50
# 58/58 [==============================] - 0s 5ms/step - loss: 0.9598 - accuracy: 0.6944
# Epoch 29/50
# 58/58 [==============================] - 0s 5ms/step - loss: 0.9647 - accuracy: 0.6875
# Epoch 30/50
# 58/58 [==============================] - 0s 5ms/step - loss: 0.9608 - accuracy: 0.6979
# Epoch 31/50
# 58/58 [==============================] - 0s 5ms/step - loss: 0.9617 - accuracy: 0.6910
# Epoch 32/50
# 58/58 [==============================] - 0s 5ms/step - loss: 0.9683 - accuracy: 0.6858
# Epoch 33/50
# 58/58 [==============================] - 0s 5ms/step - loss: 0.9580 - accuracy: 0.7014
# Epoch 34/50
# 58/58 [==============================] - 0s 5ms/step - loss: 0.9629 - accuracy: 0.6892
# Epoch 35/50
# 58/58 [==============================] - 0s 5ms/step - loss: 0.9607 - accuracy: 0.6944
# Epoch 36/50
# 58/58 [==============================] - 0s 5ms/step - loss: 0.9583 - accuracy: 0.6979
# Epoch 37/50
# 58/58 [==============================] - 0s 5ms/step - loss: 0.9676 - accuracy: 0.6788
# Epoch 38/50
# 58/58 [==============================] - 0s 5ms/step - loss: 0.9645 - accuracy: 0.6858
# Epoch 39/50
# 58/58 [==============================] - 0s 5ms/step - loss: 0.9692 - accuracy: 0.6858
# Epoch 40/50
# 58/58 [==============================] - 0s 5ms/step - loss: 0.9633 - accuracy: 0.6910
# Epoch 41/50
# 58/58 [==============================] - 0s 5ms/step - loss: 0.9561 - accuracy: 0.6979
# Epoch 42/50
# 58/58 [==============================] - 0s 5ms/step - loss: 0.9617 - accuracy: 0.6910
# Epoch 43/50
# 58/58 [==============================] - 0s 5ms/step - loss: 0.9614 - accuracy: 0.6892
# Epoch 44/50
# 58/58 [==============================] - 0s 5ms/step - loss: 0.9583 - accuracy: 0.6910
# Epoch 45/50
# 58/58 [==============================] - 0s 5ms/step - loss: 0.9573 - accuracy: 0.6962
# Epoch 46/50
# 58/58 [==============================] - 0s 5ms/step - loss: 0.9599 - accuracy: 0.6944
# Epoch 47/50
# 58/58 [==============================] - 0s 5ms/step - loss: 0.9591 - accuracy: 0.6944
# Epoch 48/50
# 58/58 [==============================] - 0s 5ms/step - loss: 0.9588 - accuracy: 0.6875
# Epoch 49/50
# 58/58 [==============================] - 0s 5ms/step - loss: 0.9588 - accuracy: 0.6910
# Epoch 50/50
# 58/58 [==============================] - 0s 5ms/step - loss: 0.9626 - accuracy: 0.6944

# %%
_,accuracy = model.evaluate(x_test,y_test)
print(accuracy*100)
# Out:
# 6/6 [==============================] - 0s 4ms/step - loss: 0.1773 - accuracy: 0.7135
# 71.35416865348816
# 2022-02-02 13:24:01.022531: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.

# %% [markdown]
# # Optimizers
# ## SGD
# ![1.png](data:image/png;base64,...)
#
# ## Adam
# ![2.png](data:image/png;base64,...)
#
# ## RMS Prop
# ![3.png](data:image/png;base64,...)
#
# # Loss Function
#
# ## Binary CrossEntropy
# ![1.png](data:image/png;base64,...)
#
# ## Mean Squared Error
# ![4.png](data:image/png;base64,...)
#
# ## Hinge
# ![5.png](data:image/png;base64,...)
